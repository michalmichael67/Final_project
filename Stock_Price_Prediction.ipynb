# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.model_selection import train_test_split
from imblearn.ensemble import BalancedRandomForestClassifier
from collections import Counter

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('Data/indexProcessed.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/0t/mmb5fhf56qg6cwbpbjllcgw80000gn/T/ipykernel_5188/1836303599.py in <module>
# ----> 1 df = pd.read_csv('Data/indexProcessed.csv')
#       2 df
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/indexProcessed.csv'

# %%
# Read indexProcessed.csv
df = pd.read_csv('Data/indexProcessed.csv')
df.dtypes
# Out:
# Index         object
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# CloseUSD     float64
# dtype: object

# %%
# Read indexInfo.csv
df_ref = pd.read_csv('Data/indexInfo.csv')
df_ref.dtypes
# Out:
# Region      object
# Exchange    object
# Index       object
# Currency    object
# dtype: object

# %%
# Merged DF 
Merged_df = pd.merge(df_ref,df, how='inner')
Merged_df
# Out:
#                Region                     Exchange    Index Currency  \
# 0       United States      New York Stock Exchange      NYA      USD
# 1       United States      New York Stock Exchange      NYA      USD
# 2       United States      New York Stock Exchange      NYA      USD
# 3       United States      New York Stock Exchange      NYA      USD
# 4       United States      New York Stock Exchange      NYA      USD
# ...               ...                          ...      ...      ...
# 104219   South Africa  Johannesburg Stock Exchange  J203.JO      ZAR
# 104220   South Africa  Johannesburg Stock Exchange  J203.JO      ZAR
# 104221   South Africa  Johannesburg Stock Exchange  J203.JO      ZAR
# 104222   South Africa  Johannesburg Stock Exchange  J203.JO      ZAR
# 104223   South Africa  Johannesburg Stock Exchange  J203.JO      ZAR
#
#               Date          Open          High           Low         Close  \
# 0       1965-12-31    528.690002    528.690002    528.690002    528.690002
# 1       1966-01-03    527.210022    527.210022    527.210022    527.210022
# 2       1966-01-04    527.840027    527.840027    527.840027    527.840027
# 3       1966-01-05    531.119995    531.119995    531.119995    531.119995
# 4       1966-01-06    532.070007    532.070007    532.070007    532.070007
# ...            ...           ...           ...           ...           ...
# 104219  2021-05-25  66054.921880  66812.453130  66022.976560  66076.679690
# 104220  2021-05-26  66076.679690  66446.367190  66030.351560  66108.226560
# 104221  2021-05-27  66108.226560  66940.250000  66102.546880  66940.250000
# 104222  2021-05-28  66940.250000  67726.562500  66794.609380  67554.859380
# 104223  2021-05-31  67554.859380  68140.851560  67554.859380  67964.039060
#
#            Adj Close  Volume     CloseUSD
# 0         528.690002     0.0   528.690002
# 1         527.210022     0.0   527.210022
# 2         527.840027     0.0   527.840027
# 3         531.119995     0.0   531.119995
# 4         532.070007     0.0   532.070007
# ...              ...     ...          ...
# 104219  66076.679690     0.0  4625.367578
# 104220  66108.226560     0.0  4627.575859
# 104221  66940.250000     0.0  4685.817500
# 104222  67554.859380     0.0  4728.840157
# 104223  67964.039060     0.0  4757.482734
#
# [104224 rows x 12 columns]

# %%
# Dataframe for NYA

df_NYA = Merged_df[Merged_df['Index'] == 'NYA']
df_NYA
# Out:
#               Region                 Exchange Index Currency        Date  \
# 0      United States  New York Stock Exchange   NYA      USD  1965-12-31
# 1      United States  New York Stock Exchange   NYA      USD  1966-01-03
# 2      United States  New York Stock Exchange   NYA      USD  1966-01-04
# 3      United States  New York Stock Exchange   NYA      USD  1966-01-05
# 4      United States  New York Stock Exchange   NYA      USD  1966-01-06
# ...              ...                      ...   ...      ...         ...
# 13942  United States  New York Stock Exchange   NYA      USD  2021-05-24
# 13943  United States  New York Stock Exchange   NYA      USD  2021-05-25
# 13944  United States  New York Stock Exchange   NYA      USD  2021-05-26
# 13945  United States  New York Stock Exchange   NYA      USD  2021-05-27
# 13946  United States  New York Stock Exchange   NYA      USD  2021-05-28
#
#                Open          High           Low         Close     Adj Close  \
# 0        528.690002    528.690002    528.690002    528.690002    528.690002
# 1        527.210022    527.210022    527.210022    527.210022    527.210022
# 2        527.840027    527.840027    527.840027    527.840027    527.840027
# 3        531.119995    531.119995    531.119995    531.119995    531.119995
# 4        532.070007    532.070007    532.070007    532.070007    532.070007
# ...             ...           ...           ...           ...           ...
# 13942  16375.000000  16508.519530  16375.000000  16464.689450  16464.689450
# 13943  16464.689450  16525.810550  16375.150390  16390.189450  16390.189450
# 13944  16390.189450  16466.339840  16388.320310  16451.960940  16451.960940
# 13945  16451.960940  16546.359380  16451.960940  16531.949220  16531.949220
# 13946  16531.949220  16588.689450  16531.949220  16555.660160  16555.660160
#
#              Volume      CloseUSD
# 0      0.000000e+00    528.690002
# 1      0.000000e+00    527.210022
# 2      0.000000e+00    527.840027
# 3      0.000000e+00    531.119995
# 4      0.000000e+00    532.070007
# ...             ...           ...
# 13942  2.947400e+09  16464.689450
# 13943  3.420870e+09  16390.189450
# 13944  3.674490e+09  16451.960940
# 13945  5.201110e+09  16531.949220
# 13946  4.199270e+09  16555.660160
#
# [13947 rows x 12 columns]

# %% [markdown]
# ## Create Target

# %%
# Find delta of today's close price from yesterday's close price 

df_NYA['Delta'] = df_NYA['Close'].diff()
df_NYA
# Out:
# C:\Users\dhava\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Region                 Exchange Index Currency        Date  \
# 0      United States  New York Stock Exchange   NYA      USD  1965-12-31
# 1      United States  New York Stock Exchange   NYA      USD  1966-01-03
# 2      United States  New York Stock Exchange   NYA      USD  1966-01-04
# 3      United States  New York Stock Exchange   NYA      USD  1966-01-05
# 4      United States  New York Stock Exchange   NYA      USD  1966-01-06
# ...              ...                      ...   ...      ...         ...
# 13942  United States  New York Stock Exchange   NYA      USD  2021-05-24
# 13943  United States  New York Stock Exchange   NYA      USD  2021-05-25
# 13944  United States  New York Stock Exchange   NYA      USD  2021-05-26
# 13945  United States  New York Stock Exchange   NYA      USD  2021-05-27
# 13946  United States  New York Stock Exchange   NYA      USD  2021-05-28
#
#                Open          High           Low         Close     Adj Close  \
# 0        528.690002    528.690002    528.690002    528.690002    528.690002
# 1        527.210022    527.210022    527.210022    527.210022    527.210022
# 2        527.840027    527.840027    527.840027    527.840027    527.840027
# 3        531.119995    531.119995    531.119995    531.119995    531.119995
# 4        532.070007    532.070007    532.070007    532.070007    532.070007
# ...             ...           ...           ...           ...           ...
# 13942  16375.000000  16508.519530  16375.000000  16464.689450  16464.689450
# 13943  16464.689450  16525.810550  16375.150390  16390.189450  16390.189450
# 13944  16390.189450  16466.339840  16388.320310  16451.960940  16451.960940
# 13945  16451.960940  16546.359380  16451.960940  16531.949220  16531.949220
# 13946  16531.949220  16588.689450  16531.949220  16555.660160  16555.660160
#
#              Volume      CloseUSD      Delta
# 0      0.000000e+00    528.690002        NaN
# 1      0.000000e+00    527.210022  -1.479980
# 2      0.000000e+00    527.840027   0.630005
# 3      0.000000e+00    531.119995   3.279968
# 4      0.000000e+00    532.070007   0.950012
# ...             ...           ...        ...
# 13942  2.947400e+09  16464.689450  89.689450
# 13943  3.420870e+09  16390.189450 -74.500000
# 13944  3.674490e+09  16451.960940  61.771490
# 13945  5.201110e+09  16531.949220  79.988280
# 13946  4.199270e+09  16555.660160  23.710940
#
# [13947 rows x 13 columns]

# %%
#  Add traget column to dataframe

df_NYA['Target'] = np.where(df_NYA['Delta']>=0, 'Up', 'Down')
df_NYA
# Out:
# C:\Users\dhava\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Region                 Exchange Index Currency        Date  \
# 0      United States  New York Stock Exchange   NYA      USD  1965-12-31
# 1      United States  New York Stock Exchange   NYA      USD  1966-01-03
# 2      United States  New York Stock Exchange   NYA      USD  1966-01-04
# 3      United States  New York Stock Exchange   NYA      USD  1966-01-05
# 4      United States  New York Stock Exchange   NYA      USD  1966-01-06
# ...              ...                      ...   ...      ...         ...
# 13942  United States  New York Stock Exchange   NYA      USD  2021-05-24
# 13943  United States  New York Stock Exchange   NYA      USD  2021-05-25
# 13944  United States  New York Stock Exchange   NYA      USD  2021-05-26
# 13945  United States  New York Stock Exchange   NYA      USD  2021-05-27
# 13946  United States  New York Stock Exchange   NYA      USD  2021-05-28
#
#                Open          High           Low         Close     Adj Close  \
# 0        528.690002    528.690002    528.690002    528.690002    528.690002
# 1        527.210022    527.210022    527.210022    527.210022    527.210022
# 2        527.840027    527.840027    527.840027    527.840027    527.840027
# 3        531.119995    531.119995    531.119995    531.119995    531.119995
# 4        532.070007    532.070007    532.070007    532.070007    532.070007
# ...             ...           ...           ...           ...           ...
# 13942  16375.000000  16508.519530  16375.000000  16464.689450  16464.689450
# 13943  16464.689450  16525.810550  16375.150390  16390.189450  16390.189450
# 13944  16390.189450  16466.339840  16388.320310  16451.960940  16451.960940
# 13945  16451.960940  16546.359380  16451.960940  16531.949220  16531.949220
# 13946  16531.949220  16588.689450  16531.949220  16555.660160  16555.660160
#
#              Volume      CloseUSD      Delta Target
# 0      0.000000e+00    528.690002        NaN   Down
# 1      0.000000e+00    527.210022  -1.479980   Down
# 2      0.000000e+00    527.840027   0.630005     Up
# 3      0.000000e+00    531.119995   3.279968     Up
# 4      0.000000e+00    532.070007   0.950012     Up
# ...             ...           ...        ...    ...
# 13942  2.947400e+09  16464.689450  89.689450     Up
# 13943  3.420870e+09  16390.189450 -74.500000   Down
# 13944  3.674490e+09  16451.960940  61.771490     Up
# 13945  5.201110e+09  16531.949220  79.988280     Up
# 13946  4.199270e+09  16555.660160  23.710940     Up
#
# [13947 rows x 14 columns]

# %%
df_NYA = df_NYA.dropna(how="any")
df_NYA
# Out:
#               Region                 Exchange Index Currency        Date  \
# 1      United States  New York Stock Exchange   NYA      USD  1966-01-03
# 2      United States  New York Stock Exchange   NYA      USD  1966-01-04
# 3      United States  New York Stock Exchange   NYA      USD  1966-01-05
# 4      United States  New York Stock Exchange   NYA      USD  1966-01-06
# 5      United States  New York Stock Exchange   NYA      USD  1966-01-07
# ...              ...                      ...   ...      ...         ...
# 13942  United States  New York Stock Exchange   NYA      USD  2021-05-24
# 13943  United States  New York Stock Exchange   NYA      USD  2021-05-25
# 13944  United States  New York Stock Exchange   NYA      USD  2021-05-26
# 13945  United States  New York Stock Exchange   NYA      USD  2021-05-27
# 13946  United States  New York Stock Exchange   NYA      USD  2021-05-28
#
#                Open          High           Low         Close     Adj Close  \
# 1        527.210022    527.210022    527.210022    527.210022    527.210022
# 2        527.840027    527.840027    527.840027    527.840027    527.840027
# 3        531.119995    531.119995    531.119995    531.119995    531.119995
# 4        532.070007    532.070007    532.070007    532.070007    532.070007
# 5        532.599976    532.599976    532.599976    532.599976    532.599976
# ...             ...           ...           ...           ...           ...
# 13942  16375.000000  16508.519530  16375.000000  16464.689450  16464.689450
# 13943  16464.689450  16525.810550  16375.150390  16390.189450  16390.189450
# 13944  16390.189450  16466.339840  16388.320310  16451.960940  16451.960940
# 13945  16451.960940  16546.359380  16451.960940  16531.949220  16531.949220
# 13946  16531.949220  16588.689450  16531.949220  16555.660160  16555.660160
#
#              Volume      CloseUSD      Delta Target
# 1      0.000000e+00    527.210022  -1.479980   Down
# 2      0.000000e+00    527.840027   0.630005     Up
# 3      0.000000e+00    531.119995   3.279968     Up
# 4      0.000000e+00    532.070007   0.950012     Up
# 5      0.000000e+00    532.599976   0.529969     Up
# ...             ...           ...        ...    ...
# 13942  2.947400e+09  16464.689450  89.689450     Up
# 13943  3.420870e+09  16390.189450 -74.500000   Down
# 13944  3.674490e+09  16451.960940  61.771490     Up
# 13945  5.201110e+09  16531.949220  79.988280     Up
# 13946  4.199270e+09  16555.660160  23.710940     Up
#
# [13946 rows x 14 columns]

# %%
list(df_NYA)
# Out:
# ['Region',
#  'Exchange',
#  'Index',
#  'Currency',
#  'Date',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Adj Close',
#  'Volume',
#  'CloseUSD',
#  'Delta',
#  'Target']

# %% [markdown]
# Below we are creating a baseline model

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

y = df_NYA['Target']
X = df_NYA[['Open',
 'High',
 'Low',
 'Close',
 'Adj Close'
           ]]

clf = LogisticRegression(random_state=0).fit(X, y)
clf.predict(X)

clf.predict_proba(X)


clf.score(X, y)
# Out:
# 0.65481141545963

# %% [markdown]
# # Split the Data into Training and Testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, = train_test_split (X,
                                                     y,
                                                     random_state =1,
                                                     stratify = y)

X_train.shape
Counter(y_train)
# Out:
# Counter({'Up': 5580, 'Down': 4879})

# %% [markdown]
# # Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

# Create a random forest classifier.
model = BalancedRandomForestClassifier(n_estimators=100, random_state=1) 

# Fitting the model
model = model.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.614647150570679

# %%
# Display the confusion matrix
#from sklearn.metrics import confusion_matrix


confusion_matrix(y_test, y_pred)
# Out:
# array([[ 981,  646],
#        [ 695, 1165]], dtype=int64)

# %%
# Print the imbalanced classification report
#from imblearn.metrics import classification_report_imbalanced

print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#        Down       0.59      0.60      0.63      0.59      0.61      0.38      1627
#          Up       0.64      0.63      0.60      0.63      0.61      0.38      1860
#
# avg / total       0.62      0.62      0.61      0.62      0.61      0.38      3487

# %%
# List the features sorted in descending order by feature importance
sorted(zip(model.feature_importances_,X.columns), reverse=True)
# Out:
# [(0.24145937331501943, 'Open'),
#  (0.19802548934441092, 'Adj Close'),
#  (0.19659097226020045, 'Close'),
#  (0.1840205920005052, 'High'),
#  (0.1799035730798641, 'Low')]

# %% [markdown]
# # SMOTE Oversampling

# %%
# Resample the training data with SMOTE
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE(random_state=1, sampling_strategy='auto').fit_resample( X_train, y_train)

# %%
Counter(y_resampled)
# Out:
# Counter({'Up': 5580, 'Down': 5580})

# %%
# Train the Logistic Regression model using the resampled data
#from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
#from sklearn.metrics import balanced_accuracy_score

y_pred = model.predict(X_test)

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.6430439624349849

# %%
# Display the confusion matrix
#from sklearn.metrics import confusion_matrix


confusion_matrix(y_test, y_pred)
# Out:
# array([[1572,   55],
#        [1265,  595]], dtype=int64)

# %%
# Print the imbalanced classification report
#from imblearn.metrics import classification_report_imbalanced

print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#        Down       0.55      0.97      0.32      0.70      0.56      0.33      1627
#          Up       0.92      0.32      0.97      0.47      0.56      0.29      1860
#
# avg / total       0.75      0.62      0.66      0.58      0.56      0.31      3487

# %% [markdown]
# # Undersampling

# %%
# Resample the data using the ClusterCentroids resampler
# Warning: This is a large dataset, and this step may take some time to complete
from imblearn.under_sampling import RandomUnderSampler
ros = RandomUnderSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

Counter(y_resampled)
# Out:
# Counter({'Down': 4879, 'Up': 4879})

# %%
# Train the Logistic Regression model using the resampled data
#from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
#from sklearn.metrics import balanced_accuracy_score

y_pred = model.predict(X_test)

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.6428136421013674

# %%
# Display the confusion matrix
#from sklearn.metrics import confusion_matrix


confusion_matrix(y_test, y_pred)
# Out:
# array([[1573,   54],
#        [1267,  593]], dtype=int64)

# %%
# Print the imbalanced classification report
#from imblearn.metrics import classification_report_imbalanced

print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#        Down       0.55      0.97      0.32      0.70      0.56      0.33      1627
#          Up       0.92      0.32      0.97      0.47      0.56      0.29      1860
#
# avg / total       0.75      0.62      0.66      0.58      0.56      0.31      3487
